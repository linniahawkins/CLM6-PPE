# %%
import numpy as np
import pandas as pd
import xarray as xr
import os, json
import tensorflow as tf
from scipy.stats import qmc

# %%
# get config information
utils_dir = '/glade/u/home/linnia/CLM6-PPE/utils/'

with open(os.path.join(utils_dir, "param_info.json"), "r") as f:
    param_info = json.load(f)

with open(os.path.join(utils_dir, "biome_info.json"), "r") as f:
    biome_info = json.load(f)

universal_param_names = param_info['u_params']
pft_param_names = param_info['pft_params']
n_universal_params = len(param_info['u_params'])
n_pft_params = len(param_info['pft_params']) # Number of parameters per PFT

# %%
# load observational data
obs = xr.open_dataset('~/ctsm6_ppe/analysis_lhc/wave3/wave3_obsStatistics_sudokuBiomes.nc')

# %%
# create universal sample
n_samples = 1000

sampler = qmc.LatinHypercube(d=n_universal_params)

s = sampler.random(n=n_samples)
universal_parameter_samples = pd.DataFrame(s,columns=universal_param_names)

# %%
# stack up all your observational data and emulators for each input metric (variable and biome)
paths = {
    'lai': './emulators/biome_lai_',
}

biomes = [13]
obs_mean = []
obs_var = []
emulators = [] 
biome_list = [] 

for b in biomes:
    biome_list.append(str(b))

    obs_mean.append(obs.LAI_mean.isel(biome=b).values)
    obs_var.append(obs.LAI_stdev.isel(biome=b).values**2)

    emulators.append(tf.saved_model.load(paths['lai']+str(b)))

# %%
n_pfts = 14
n_psamp = 1000
I_tolerance = 3.0 # implausibility tolerance (defined as float)

all_nroy_param_sets_from_universal = [] # List to collect NROY sets from each universal sample

# Loop over each universal parameter sample
#for u_idx in range(len(universal_parameter_samples)):
for u_idx in range(100):
    # create sample (dataframe) for the current universal parameter set
    usample_values = np.tile(universal_parameter_samples.iloc[[u_idx]].values,(n_psamp,1))
    psample_values = np.random.rand(n_psamp,n_pfts*n_pft_params)
    combined_values = np.concatenate([usample_values,psample_values],axis=1)

    all_pft_param_column_names = []
    for pft_id in range(1, n_pfts + 1):
        for param_name in pft_param_names:
            all_pft_param_column_names.append(f"pft{pft_id}_{param_name}")
    all_columns = universal_param_names + all_pft_param_column_names
    sample_df = pd.DataFrame(combined_values, columns=all_columns)


    # History matching for the current universal parameter set
    num_metrics = len(emulators)
    all_implausibilities_for_samples = np.empty((n_psamp, num_metrics))

    for metric_ix in range(num_metrics):
        biome_id = str(biome_list[metric_ix]) # Ensure biome_id is an integer for dict lookup
        emulator_object = emulators[metric_ix] # Corrected: access emulator from a list/array

        # call_emulator expects biome_info as dict
        y_pred, y_pred_var = call_biome_emulator(sample_df, biome_id, emulator_object, biome_info)

        # calc_Implausibility should return a 1D array of implausibility values for all 'n_psamp' samples
        metric_I = calc_Implausibility(y_pred, y_pred_var, obs_mean[metric_ix], obs_var[metric_ix])
        
        # Store the implausibility values for the current biome/metric
        all_implausibilities_for_samples[:, metric_ix] = metric_I.squeeze()

    # identify parameter sets that are Not Ruled Out Yet for the current universal sample
    is_nroy_mask = (all_implausibilities_for_samples < I_tolerance).all(axis=1)
    current_u_nroy_param_sets = sample_df[is_nroy_mask]
    
    # Append the NROY sets found for this universal parameter to the master list
    all_nroy_param_sets_from_universal.append(current_u_nroy_param_sets)

    print(f"For universal sample {u_idx}: Found {len(current_u_nroy_param_sets)} NROY parameter sets out of {n_psamp} samples.")

# Concatenate all NROY_param_sets from all universal samples
NROY_param_sets = pd.concat(all_nroy_param_sets_from_universal).reset_index(drop=True)
# Out:
# For universal sample 0: Found 60 NROY parameter sets out of 1000 samples.
# For universal sample 1: Found 918 NROY parameter sets out of 1000 samples.
# For universal sample 2: Found 909 NROY parameter sets out of 1000 samples.
# For universal sample 3: Found 852 NROY parameter sets out of 1000 samples.
# For universal sample 4: Found 994 NROY parameter sets out of 1000 samples.
# For universal sample 5: Found 508 NROY parameter sets out of 1000 samples.
# For universal sample 6: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 7: Found 996 NROY parameter sets out of 1000 samples.
# For universal sample 8: Found 967 NROY parameter sets out of 1000 samples.
# For universal sample 9: Found 997 NROY parameter sets out of 1000 samples.
# For universal sample 10: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 11: Found 890 NROY parameter sets out of 1000 samples.
# For universal sample 12: Found 972 NROY parameter sets out of 1000 samples.
# For universal sample 13: Found 838 NROY parameter sets out of 1000 samples.
# For universal sample 14: Found 347 NROY parameter sets out of 1000 samples.
# For universal sample 15: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 16: Found 998 NROY parameter sets out of 1000 samples.
# For universal sample 17: Found 726 NROY parameter sets out of 1000 samples.
# For universal sample 18: Found 964 NROY parameter sets out of 1000 samples.
# For universal sample 19: Found 991 NROY parameter sets out of 1000 samples.
# For universal sample 20: Found 995 NROY parameter sets out of 1000 samples.
# For universal sample 21: Found 489 NROY parameter sets out of 1000 samples.
# For universal sample 22: Found 772 NROY parameter sets out of 1000 samples.
# For universal sample 23: Found 973 NROY parameter sets out of 1000 samples.
# For universal sample 24: Found 996 NROY parameter sets out of 1000 samples.
# For universal sample 25: Found 998 NROY parameter sets out of 1000 samples.
# For universal sample 26: Found 999 NROY parameter sets out of 1000 samples.
# For universal sample 27: Found 879 NROY parameter sets out of 1000 samples.
# For universal sample 28: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 29: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 30: Found 985 NROY parameter sets out of 1000 samples.
# For universal sample 31: Found 889 NROY parameter sets out of 1000 samples.
# For universal sample 32: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 33: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 34: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 35: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 36: Found 977 NROY parameter sets out of 1000 samples.
# For universal sample 37: Found 908 NROY parameter sets out of 1000 samples.
# For universal sample 38: Found 997 NROY parameter sets out of 1000 samples.
# For universal sample 39: Found 996 NROY parameter sets out of 1000 samples.
# For universal sample 40: Found 950 NROY parameter sets out of 1000 samples.
# For universal sample 41: Found 887 NROY parameter sets out of 1000 samples.
# For universal sample 42: Found 979 NROY parameter sets out of 1000 samples.
# For universal sample 43: Found 934 NROY parameter sets out of 1000 samples.
# For universal sample 44: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 45: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 46: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 47: Found 908 NROY parameter sets out of 1000 samples.
# For universal sample 48: Found 998 NROY parameter sets out of 1000 samples.
# For universal sample 49: Found 593 NROY parameter sets out of 1000 samples.
# For universal sample 50: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 51: Found 999 NROY parameter sets out of 1000 samples.
# For universal sample 52: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 53: Found 980 NROY parameter sets out of 1000 samples.
# For universal sample 54: Found 738 NROY parameter sets out of 1000 samples.
# For universal sample 55: Found 956 NROY parameter sets out of 1000 samples.
# For universal sample 56: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 57: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 58: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 59: Found 999 NROY parameter sets out of 1000 samples.
# For universal sample 60: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 61: Found 971 NROY parameter sets out of 1000 samples.
# For universal sample 62: Found 991 NROY parameter sets out of 1000 samples.
# For universal sample 63: Found 932 NROY parameter sets out of 1000 samples.
# For universal sample 64: Found 997 NROY parameter sets out of 1000 samples.
# For universal sample 65: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 66: Found 990 NROY parameter sets out of 1000 samples.
# For universal sample 67: Found 992 NROY parameter sets out of 1000 samples.
# For universal sample 68: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 69: Found 602 NROY parameter sets out of 1000 samples.
# For universal sample 70: Found 973 NROY parameter sets out of 1000 samples.
# For universal sample 71: Found 990 NROY parameter sets out of 1000 samples.
# For universal sample 72: Found 848 NROY parameter sets out of 1000 samples.
# For universal sample 73: Found 956 NROY parameter sets out of 1000 samples.
# For universal sample 74: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 75: Found 541 NROY parameter sets out of 1000 samples.
# For universal sample 76: Found 902 NROY parameter sets out of 1000 samples.
# For universal sample 77: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 78: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 79: Found 999 NROY parameter sets out of 1000 samples.
# For universal sample 80: Found 987 NROY parameter sets out of 1000 samples.
# For universal sample 81: Found 666 NROY parameter sets out of 1000 samples.
# For universal sample 82: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 83: Found 990 NROY parameter sets out of 1000 samples.
# For universal sample 84: Found 988 NROY parameter sets out of 1000 samples.
# For universal sample 85: Found 778 NROY parameter sets out of 1000 samples.
# For universal sample 86: Found 827 NROY parameter sets out of 1000 samples.
# For universal sample 87: Found 861 NROY parameter sets out of 1000 samples.
# For universal sample 88: Found 807 NROY parameter sets out of 1000 samples.
# For universal sample 89: Found 689 NROY parameter sets out of 1000 samples.
# For universal sample 90: Found 836 NROY parameter sets out of 1000 samples.
# For universal sample 91: Found 514 NROY parameter sets out of 1000 samples.
# For universal sample 92: Found 965 NROY parameter sets out of 1000 samples.
# For universal sample 93: Found 788 NROY parameter sets out of 1000 samples.
# For universal sample 94: Found 982 NROY parameter sets out of 1000 samples.
# For universal sample 95: Found 1000 NROY parameter sets out of 1000 samples.
# For universal sample 96: Found 758 NROY parameter sets out of 1000 samples.
# For universal sample 97: Found 803 NROY parameter sets out of 1000 samples.
# For universal sample 98: Found 990 NROY parameter sets out of 1000 samples.
# For universal sample 99: Found 999 NROY parameter sets out of 1000 samples.
